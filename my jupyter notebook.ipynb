# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Raunak Rathod
# STUDENT

# %% [markdown]
# *I love Data science because i am very much interested in business and data science  helps to bring out an insight in any business by understand the market data*

# %% [markdown]
# Printing a pattern

# %%
num = 5
for n in range(1, num):
    for i in range(1, n+1):
        print(i, end=" ")
    print("")
